# %%
from PIL import Image

# %%
mask = Image.open('mask.png')
matrix = Image.open('word_matrix.png')

# %%
mask
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=505x251>

# %%
matrix
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1015x559>

# %%
matrix.size
# Out:
# (1015, 559)

# %%
mask.size
# Out:
# (505, 251)

# %%
matrix_new = matrix.resize((505,251))

# %%
matrix_new.paste(im=mask, box=((0,0)), mask=mask)

# %%
matrix_new
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>

# %%
matrix_new.putalpha(150)

# %%
matrix_new
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>

# %%
matrix = matrix.resize((505,251))

# %%
matrix.paste(matrix_new, (0,0), matrix_new)

# %%
matrix
# Out:
# <PIL.Image.Image image mode=RGBA size=505x251>
